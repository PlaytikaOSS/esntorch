# %% [markdown]
# # DistilBERT finetuning on SST-2

# %%
# !pip install transformers
# !pip install datasets
# !pip install ipywidgets

# %% [markdown]
# ## Librairy

# %%
import os
import time
import pickle

import numpy as np
import torch

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

from transformers import DistilBertTokenizer, DistilBertTokenizerFast
from transformers import DistilBertForSequenceClassification, AdamW
from transformers import Trainer, TrainingArguments
from transformers import EarlyStoppingCallback
from transformers.data.data_collator import DataCollatorWithPadding

from datasets import load_dataset, Dataset, concatenate_datasets

# %%
# print(torch.__version__)
# print(torch.cuda.device_count())
# print(torch.cuda.is_available())
# print(torch.cuda.get_device_name(0))

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# if torch.cuda.is_available():
#     torch.set_default_tensor_type('torch.cuda.FloatTensor')

device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Global variables

# %%
BATCH_SIZE = 24 # cf. paper Sun et al.
NB_EPOCHS = 4   # cf. paper Sun et al.

# %%
# CURRENT_PATH = '~/Results/BERT_finetune' # fake path for deployment
CURRENT_PATH = '/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2'

# %%
RESULTS_FILE = os.path.join(CURRENT_PATH, 'sst-2_results.pkl')
RESULTS_DIR = os.path.join(CURRENT_PATH,'sst-2/')

# %%
# CACHE_DIR = '~/Data/huggignface/'         # path of your folder
CACHE_DIR = '/raid/home/jeremiec/huggingface_datasets'

# %% [markdown]
# ## Dataset

# %%
# download dataset

# train set
raw_datasets = load_dataset('glue', 'sst2', cache_dir=CACHE_DIR)
raw_datasets = raw_datasets.rename_column('sentence', 'text')

# special test set
raw_test_set = load_dataset('gpt3mix/sst2', split='test', cache_dir=CACHE_DIR)

def clean(example):
    example['text'] = example['text'].replace('-LRB-', '(').replace('-RRB-', ')').replace(r'\/', r'/')
    example['label'] = np.abs(example['label'] - 1) # revert labels of test set
    return example

raw_test_set = raw_test_set.map(clean)

raw_datasets['test'] = raw_test_set
# Out:
# Reusing dataset glue (/raid/home/jeremiec/huggingface_datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Using custom data configuration default
# Reusing dataset sst2 (/raid/home/jeremiec/huggingface_datasets/gpt3mix___sst2/default/0.0.0/90167692658fa4abca2ffa3ede1a43a71e2bf671078c5c275c64c4231d5a62fa)
# Loading cached processed dataset at /raid/home/jeremiec/huggingface_datasets/gpt3mix___sst2/default/0.0.0/90167692658fa4abca2ffa3ede1a43a71e2bf671078c5c275c64c4231d5a62fa/cache-3781b546d2425b83.arrow

# %%
# tokenize

tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

def tokenize_function(examples):
    return tokenizer(examples["text"], padding=True, truncation=True)

tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
tokenized_datasets = tokenized_datasets.rename_column('label', 'labels')
tokenized_datasets.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

train_dataset = tokenized_datasets["train"].shuffle(seed=42)
test_dataset = tokenized_datasets["test"].shuffle(seed=42)
val_dataset = tokenized_datasets["validation"].shuffle(seed=42)
# Out:
# Loading cached processed dataset at /raid/home/jeremiec/huggingface_datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-a0ee31821520c8d6.arrow
# Loading cached processed dataset at /raid/home/jeremiec/huggingface_datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-2f14b58aff62a8ad.arrow
# Loading cached processed dataset at /raid/home/jeremiec/huggingface_datasets/gpt3mix___sst2/default/0.0.0/90167692658fa4abca2ffa3ede1a43a71e2bf671078c5c275c64c4231d5a62fa/cache-25b1d5f21e1359a0.arrow
# Loading cached shuffled indices for dataset at /raid/home/jeremiec/huggingface_datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-bafc871e3e98ccd3.arrow
# Loading cached shuffled indices for dataset at /raid/home/jeremiec/huggingface_datasets/gpt3mix___sst2/default/0.0.0/90167692658fa4abca2ffa3ede1a43a71e2bf671078c5c275c64c4231d5a62fa/cache-36333c1a39f93c75.arrow
# Loading cached shuffled indices for dataset at /raid/home/jeremiec/huggingface_datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-003abcbefcff10df.arrow

# %%
# get number of labels

num_labels = len(set(train_dataset['labels'].tolist()))
num_labels
# Out:
# 2

# %% [markdown]
# ## Model

# %% [markdown]
# #### Model

# %%
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=num_labels)
model.to(device)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# #### Training

# %%
training_args = TrainingArguments(
    
    # output
    output_dir=RESULTS_DIR,          
    
    # params
    num_train_epochs=NB_EPOCHS,               # nb of epochs
    per_device_train_batch_size=BATCH_SIZE,   # batch size per device during training
    per_device_eval_batch_size=BATCH_SIZE,    # cf. paper Sun et al.
    learning_rate=2e-5,                       # cf. paper Sun et al.
#     warmup_steps=500,                         # number of warmup steps for learning rate scheduler
    warmup_ratio=0.1,                         # cf. paper Sun et al.
    weight_decay=0.01,                        # strength of weight decay
    
#     # eval
    evaluation_strategy="steps",              # cf. paper Sun et al.
    eval_steps=50, # 20                       # cf. paper Sun et al.
#     evaluation_strategy='no', # no more evaluation, takes time
    
    # log
    logging_dir=RESULTS_DIR+'logs',  
    logging_strategy='steps',
    logging_steps=50, # 20
    
    # save
    save_strategy='steps',
    save_total_limit=1,
    # save_steps=20, # default 500
    load_best_model_at_end=True,              # cf. paper Sun et al.
    metric_for_best_model='eval_loss'    
)

# %%
def compute_metrics(p):
    
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    
    return {"val_accuracy": accuracy}

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    # compute_metrics=compute_metrics,
    # callbacks=[EarlyStoppingCallback(early_stopping_patience=5)]
)

# %%
results = trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running training *****
#   Num examples = 67349
#   Num Epochs = 4
#   Instantaneous batch size per device = 24
#   Total train batch size (w. parallel, distributed & accumulation) = 24
#   Gradient Accumulation steps = 1
#   Total optimization steps = 11228
#     <div>
#
#       <progress value='11228' max='11228' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11228/11228 15:30, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.691700</td>
#       <td>0.688041</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.684000</td>
#       <td>0.683429</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.670900</td>
#       <td>0.667243</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.636100</td>
#       <td>0.565200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.464100</td>
#       <td>0.415778</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.392800</td>
#       <td>0.372551</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.332400</td>
#       <td>0.356897</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.345500</td>
#       <td>0.347966</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.293900</td>
#       <td>0.333738</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.331900</td>
#       <td>0.320313</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.284800</td>
#       <td>0.333590</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.301000</td>
#       <td>0.300992</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.280100</td>
#       <td>0.279929</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.274100</td>
#       <td>0.310704</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.287300</td>
#       <td>0.305612</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.274300</td>
#       <td>0.311642</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.299300</td>
#       <td>0.274399</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.254200</td>
#       <td>0.267643</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.272900</td>
#       <td>0.262196</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.228400</td>
#       <td>0.272520</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.245600</td>
#       <td>0.299886</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.234100</td>
#       <td>0.294312</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.275600</td>
#       <td>0.317769</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.236500</td>
#       <td>0.296550</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.248200</td>
#       <td>0.281285</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.232300</td>
#       <td>0.317865</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.203800</td>
#       <td>0.260196</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.233500</td>
#       <td>0.249674</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.232300</td>
#       <td>0.274987</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.231200</td>
#       <td>0.331518</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.227100</td>
#       <td>0.299668</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.204500</td>
#       <td>0.300225</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.215700</td>
#       <td>0.298291</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.248600</td>
#       <td>0.289342</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.197700</td>
#       <td>0.345561</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.194900</td>
#       <td>0.276857</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.212300</td>
#       <td>0.256153</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.212100</td>
#       <td>0.249698</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.206400</td>
#       <td>0.258930</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.222400</td>
#       <td>0.233441</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.206500</td>
#       <td>0.249089</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.194900</td>
#       <td>0.263299</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.189300</td>
#       <td>0.357454</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.188400</td>
#       <td>0.322113</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.199000</td>
#       <td>0.247037</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.232100</td>
#       <td>0.254041</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.205900</td>
#       <td>0.269879</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.188400</td>
#       <td>0.272107</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.203700</td>
#       <td>0.257160</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.199200</td>
#       <td>0.267383</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.173200</td>
#       <td>0.258103</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.182900</td>
#       <td>0.233077</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.199200</td>
#       <td>0.273903</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.168300</td>
#       <td>0.282338</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.199900</td>
#       <td>0.249081</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.188600</td>
#       <td>0.255041</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.143700</td>
#       <td>0.286954</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.161500</td>
#       <td>0.335192</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.121700</td>
#       <td>0.302569</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.151900</td>
#       <td>0.328692</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.127100</td>
#       <td>0.320218</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.140800</td>
#       <td>0.415330</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.121400</td>
#       <td>0.320367</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.128000</td>
#       <td>0.366976</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.150400</td>
#       <td>0.289215</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.128700</td>
#       <td>0.311685</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.165400</td>
#       <td>0.289384</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.126400</td>
#       <td>0.313029</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.136400</td>
#       <td>0.321162</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.153900</td>
#       <td>0.299979</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>0.106300</td>
#       <td>0.335837</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.134100</td>
#       <td>0.338983</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>0.105500</td>
#       <td>0.372725</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.116400</td>
#       <td>0.354550</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>0.114100</td>
#       <td>0.322560</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.157300</td>
#       <td>0.305846</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>0.136400</td>
#       <td>0.365060</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.109900</td>
#       <td>0.346912</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>0.132800</td>
#       <td>0.331657</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.133300</td>
#       <td>0.387284</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>0.121800</td>
#       <td>0.361195</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.135000</td>
#       <td>0.337906</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>0.128900</td>
#       <td>0.334455</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.156200</td>
#       <td>0.279559</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>0.103200</td>
#       <td>0.304259</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.151600</td>
#       <td>0.300875</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>0.133600</td>
#       <td>0.281886</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.150300</td>
#       <td>0.262041</td>
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1000] due to args.save_total_limit
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-1500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2500/special_tokens_map.json
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-3500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4500/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-5500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-6000] due to args.save_total_limit
# ...
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-8500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9500/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-9500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10500
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10500/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10500/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-11000
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-11000/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-11000/special_tokens_map.json
# Deleting older checkpoint [/raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-10500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
# The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: idx, text.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 24
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint-2000 (score: 0.23344102501869202).

# %%
training_time = results.metrics["train_runtime"]
training_time_per_epoch = training_time / training_args.num_train_epochs
training_time_per_epoch
# Out:
# 232.84875

# %%
trainer.save_model(os.path.join(RESULTS_DIR, 'checkpoint_best_model'))
# Out:
# Saving model checkpoint to /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint_best_model
# Configuration saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint_best_model/config.json
# Model weights saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint_best_model/pytorch_model.bin
# tokenizer config file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint_best_model/tokenizer_config.json
# Special tokens file saved in /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint_best_model/special_tokens_map.json

# %% [markdown]
# ## Results

# %%
# load model
model_file = os.path.join(RESULTS_DIR, 'checkpoint_best_model')
finetuned_model = DistilBertForSequenceClassification.from_pretrained(model_file, num_labels=num_labels)
finetuned_model.to(device)
finetuned_model.eval()

# compute test acc
test_trainer = Trainer(finetuned_model, data_collator=DataCollatorWithPadding(tokenizer))
raw_preds, labels, _ = test_trainer.predict(test_dataset)
preds = np.argmax(raw_preds, axis=1)
test_acc = accuracy_score(y_true=labels, y_pred=preds)

# save results
results_d = {}
results_d['accuracy'] = test_acc
results_d['training_time'] = training_time
# Out:
# loading configuration file /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint_best_model/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.15.0",
#   "vocab_size": 30522
# }
#
# loading weights file /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint_best_model/pytorch_model.bin
# All model checkpoint weights were used when initializing DistilBertForSequenceClassification.
#
# All the weights of DistilBertForSequenceClassification were initialized from the model checkpoint at /raid/home/jeremiec/Ax_results/DistilBERT_finetune_v2/sst-2/checkpoint_best_model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForSequenceClassification for predictions without further training.
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the test set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.
# ***** Running Prediction *****
#   Num examples = 1821
#   Batch size = 8
#     <div>
#
#       <progress value='228' max='228' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [228/228 00:02]
#     </div>

# %%
results_d
# Out:
# {'accuracy': 0.9126853377265239, 'training_time': 931.395}

# %%
# save results

with open(RESULTS_FILE, 'wb') as fh:
    pickle.dump(results_d, fh)
